# %% [markdown]
# <a href="https://colab.research.google.com/github/aryancodes12/Advance-Machine-Learning/blob/main/streamlit_salary_prediction_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib

model = joblib.load('salary_prediction_model.pkl')
encoder = joblib.load('label_encoder.pkl')


st.title("Salary Prediction Model")

age = st.number_input("Age")
gender = st.selectbox("Gender", encoder["Gender"].classes_)
education_level = st.selectbox("Education Level", encoder['Education Level'].classes_)
job_title = st.selectbox("Job Title", encoder['Job Title'].classes_)
years_of_experience = st.number_input("Years of Experience")

df = pd.DataFrame({
    'Age': [age],
    'Gender': [gender],
    'Education Level': [education_level],
    'Job Title': [job_title],
    'Years of Experience': [years_of_experience]
})


if st.button("Predict Salary"):
  for col in encoder:
    df(col) = encoder[col].transform(df[col])

  prediction = model.predict(df)
  st.success(f"Predicted Salary: {prediction[0]:,.2f}")
